# %% [markdown]
# ### 1. Import libraries

# %%
import pandas as pd
import matplotlib.pyplot as pp
# %matplotlib inline
import seaborn as sb
sb.set()

# %% [markdown]
# ### 2. Read/Import the data set

# %%
data1=pd.read_csv('titanic1.csv')
data1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### 3. EXPLORATORY DATA ANALYSIS (EDA)

# %%
#THE SHAPE OF THE DATA SET WHICH SHOWS THE NUMBER OF ROWS AND COLUMNS PRESENT IN THE DATA SET
data1.shape
# Out:
# (891, 12)

# %%
#SUMMARY OF THE DATA SET
data1.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ### Exploring and Analyzing the Data

# %% [markdown]
# ### Feature(s) Data Types

# %%
data1.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# ### Number of Survives Passengers

# %%
data1['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %% [markdown]
# ### Gender wise count

# %%
gender_count=data1['Sex'].value_counts()
gender_count
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %% [markdown]
# ### Data visualization for male and female count

# %%
data1['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
pp.barh(data1['Sex'].unique(),gender_count)
pp.grid(True)

# %% [markdown]
# ### Fare Histogram

# %%
pp.hist(data1['Fare'])
pp.grid(True)

# %% [markdown]
# ### 4. DATA CLEANING

# %% [markdown]
# ### Bar chart plots for categorical features
#
# PClass, Sex, SibSp, Parch, Embarked, Cabin

# %%
data2=data1.copy()
#Defining a function with name bar_chart

def bar_chart(feature):
    survived=data2[data2['Survived']==1][feature].value_counts()
    dead=data2[data2['Survived']==0][feature].value_counts()
    data3=pd.DataFrame([survived,dead])
    data3.index=['Survived','Dead']
    #sb.barplot(data3.index,survived)
    #sb.barplot(data3.index,dead)
    data3.plot(kind='bar',stacked=True,figsize=(10,5))

# %% [markdown]
# ### Gender based survival

# %%
bar_chart('Sex')

# %% [markdown]
# ### PClass (ticket class) based survival

# %%
bar_chart('Pclass')

# %% [markdown]
# ### SibSp (sibling(s)/spouse) based survival

# %%
bar_chart('SibSp')

# %% [markdown]
# ### Parch (Parent/child(ren)) based survival

# %%
bar_chart('Parch')

# %% [markdown]
# ### Tiltle (Mr,Mrs,etc) based survival

# %%
data3=[data1]
for data in data3:
    data['Title']=data['Name'].str.extract('([A-Za-z]+)\.',expand=False)

# %%
data1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### Title count

# %%
data1['Title'].value_counts()
# Out:
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Mlle          2
# Major         2
# Col           2
# Countess      1
# Capt          1
# Ms            1
# Sir           1
# Lady          1
# Mme           1
# Don           1
# Jonkheer      1
# Name: Title, dtype: int64

# %%
data1['Title'].unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Don', 'Rev', 'Dr', 'Mme', 'Ms',
#        'Major', 'Lady', 'Sir', 'Mlle', 'Col', 'Capt', 'Countess',
#        'Jonkheer'], dtype=object)

# %%
data2=data1.copy()
#Defining a function with name bar_chart

def bar_chart(feature):
    survived=data2[data2['Survived']==1][feature].value_counts()
    dead=data2[data2['Survived']==0][feature].value_counts()
    data3=pd.DataFrame([survived,dead])
    data3.index=['Survived','Dead']
    #sb.barplot(data3.index,survived)
    #sb.barplot(data3.index,dead)
    data3.plot(kind='bar',stacked=True,figsize=(10,5))

# %%
bar_chart('Title')

# %% [markdown]
# ### mapping the title values

# %%
data1['Title'].replace(['Mr', 'Mrs', 'Miss', 'Master', 'Don', 'Rev', 'Dr', 'Mme', 'Ms',
       'Major', 'Lady', 'Sir', 'Mlle', 'Col', 'Capt', 'Countess',
       'Jonkheer'],[0,1,2,3,3,3,3,3,3,3,3,3,3,3,3,3,3],inplace=True)

# %%
data1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### Filling the missing values in the data set

# %%
data1.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# Title            0
# dtype: int64

# %% [markdown]
# ### filling the missing ages

# %%
nan_ages=data1[data1['Age'].isnull()]
nan_ages
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
mean_ages=data1.groupby(['Sex','Pclass'])['Age'].mean()
mean_ages
# Out:
# Sex     Pclass
# female  1         34.611765
#         2         28.722973
#         3         21.750000
# male    1         41.281386
#         2         30.740707
#         3         26.507589
# Name: Age, dtype: float64

# %%
#Making a function to fill the NaN age(s)
def fill_nan_ages(row):
    if pd.isnull(row['Age']):
        return mean_ages[row['Sex'],row['Pclass']]
    else:
        return row['Age']

# %%
data1['Age']=data1.apply(fill_nan_ages,axis=1)
data1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex    Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.00      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.00      1
# 2                               Heikkinen, Miss. Laina  female  26.00      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.00      1
# 4                             Allen, Mr. William Henry    male  35.00      0
# ...

# %%
data1['Age'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Converting numerical Age to categorical values (Binning)

# %%
data1['Age'].hist()
# Out:
# <AxesSubplot:>

# %%
labels=['Child','Teenager','Young Adult','Mid-Aged Adult','Old Adult']

data1['AgeClass']=pd.cut(data1['Age'],bins=5,labels=labels)
data1['AgeClass'].value_counts()
# Out:
# Teenager          493
# Young Adult       218
# Child             100
# Mid-Aged Adult     69
# Old Adult          11
# Name: AgeClass, dtype: int64

# %%
data1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Title     AgeClass
# 0      0         A/5 21171   7.2500   NaN        S      0     Teenager
# 1      0          PC 17599  71.2833   C85        C      1  Young Adult
# 2      0  STON/O2. 3101282   7.9250   NaN        S      2     Teenager
# ...

# %% [markdown]
# ### Age based survival

# %%
bar_chart('AgeClass')

# %% [markdown]
# ### Exporting the cleaned file to csv

# %%
data1.to_csv('cleaned_titanic1.csv')

# %%
cleaned_titanic1=pd.read_csv('cleaned_titanic1.csv')
cleaned_titanic1
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex    Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.00      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.00      1
# 2                               Heikkinen, Miss. Laina  female  26.00      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.00      1
# ...
